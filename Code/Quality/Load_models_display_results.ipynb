# %%
from pathlib import Path
import pandas as pd

from utils import *
from dataloaders import *
from data_preparation import *
from allResNets import *
from MobileNetV3 import *
from engine import *
from efficientNet import *
from data_transforms import *

change_to_disk()
models_path = Path('Quality/Models_test')
saves = Path('Trainning_results_saves/')

# %%
NUM_EPOCHS = 100
lr = 0.001
device = get_device()

resnet18 = ResNet18()
resnet50 = ResNet50()
mobnet_sml = MobileNetV3("small")
mobnet_lrg = MobileNetV3("large")
effnetb0 = EfficientNetB0()
effnetb5 = EfficientNetB5()

loss_fn = nn.CrossEntropyLoss()

# %%
model_name = "ResNet18"
model = ResNet18
res18_results, final_res18_model, best_res18_model = load_results_model(model_name, models_path, model, NUM_EPOCHS, 35, device)
print("Done")
# Out:
# Done

# %%
model_name = "ResNet50"
model = ResNet50
res50_results, final_res50_model, best_res50_model = load_results_model(model_name, models_path, model, NUM_EPOCHS, 78, device)

print("Done")
# Out:
# Done

# %%
model_name = "MobileNetSmall"
model = MobileNetSmall
mobnet_sml_results, final_mobnet_sml_model, best_mobnet_sml_model = load_results_model(model_name, models_path, model, NUM_EPOCHS, 70, device)
print("Done")
# Out:
# Done

# %%
model_name = "MobileNetLarge"
model = MobileNetLarge
mobnet_lrg_results, final_mobnet_lrg_model, best_mobnet_lrg_model = load_results_model(model_name, models_path, model, NUM_EPOCHS, 94, device)
print("Done")
# Out:
# Done

# %%
model_name = "EfficientNetB0"
model = EfficientNetB0
effnetb0_results, final_effnetb0_model, best_effnetb0_model = load_results_model(model_name, models_path, model, NUM_EPOCHS, 31, device)
print("Done")
# Out:
# Done

# %%
models_results = [
    res18_results[0],
    res50_results[0],
    mobnet_sml_results[0],
    mobnet_lrg_results[0],
    effnetb0_results[0]
]

models_titles =[
    "ResNet18",
    "ResNet50",
    "MobileNet V3 Small",
    "MobileNet V3 Large",
    "EfficientNet B0"
]

plot_all_loss_curves(models_results, models_titles)

# %%
plot_loss_curves(effnetb0_results[0],"EfficientNetB0")
