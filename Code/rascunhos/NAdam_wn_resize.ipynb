# %%
from pathlib import Path
import pandas as pd

from utils import *
from dataloaders import *
from data_preparation import *
from allResNets import *
from MobileNetV3 import *
from engine import *
from efficientNet import *
from data_transforms import *

change_to_disk()
data_dir = Path("clean_split_1k/")
models_path = Path('Models/')
saves = Path('Trainning_results_saves/')

# %%
image_shape = (1920, 1080)
resize_factor = 0.3
resize = np.multiply(image_shape,resize_factor)
resize = [int(resize[1]), int(resize[0])]

data_transform = create_transform(resize=resize, rotate=180, color_dev=True, transf_tensor=True, normalize=True, sp_noise=True, gauss_noise=True)

BATCH_SIZE = 16
train_dl, validation_dl, test_dl, train_data, validation_data, test_data, class_names = create_dataloaders(data_dir, data_transform, batch_size = BATCH_SIZE)

# %%
NUM_EPOCHS = 100
lr = 0.001
device = get_device()

resnet18 = ResNet18()
resnet50 = ResNet50()
mobnet_sml = MobileNetSmall()
mobnet_lrg = MobileNetLarge()
effnetb0 = EfficientNetB0()
effnetb5 = EfficientNetB5()

loss_fn = nn.CrossEntropyLoss()

# %%
model_name = "ResNet18_Noise"
model_folder_path = models_path / model_name
check_dir(model_folder_path)
model_name_folder_path = model_folder_path / model_name

#Train ResNet18
resnet18.to(device)
nadam_optim = torch.optim.NAdam(params=resnet18.parameters(), lr=lr)
train_resnet18_results, train_time_resnet18 = train(resnet18, train_dl, validation_dl, optimizer=nadam_optim, loss_fn=loss_fn, epochs=NUM_EPOCHS, name_save=model_name_folder_path, device=device)
# Out:
# Models\ResNet18_Noise does not exist, creating one...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.9259 | train_acc: 0.5717 | validation_loss: 0.7686 | validation_acc: 0.6328
# Epoch: 2 | train_loss: 0.7602 | train_acc: 0.6490 | validation_loss: 1.0845 | validation_acc: 0.4961
# Epoch: 3 | train_loss: 0.7268 | train_acc: 0.6558 | validation_loss: 0.9474 | validation_acc: 0.5176
# Epoch: 4 | train_loss: 0.6762 | train_acc: 0.6895 | validation_loss: 0.7647 | validation_acc: 0.6426
# Epoch: 5 | train_loss: 0.6267 | train_acc: 0.7125 | validation_loss: 0.6482 | validation_acc: 0.7012
# Epoch: 6 | train_loss: 0.5987 | train_acc: 0.7250 | validation_loss: 0.7688 | validation_acc: 0.6367
# Epoch: 7 | train_loss: 0.5951 | train_acc: 0.7262 | validation_loss: 0.6666 | validation_acc: 0.6660
# Epoch: 8 | train_loss: 0.5722 | train_acc: 0.7385 | validation_loss: 0.8243 | validation_acc: 0.6289
# Epoch: 9 | train_loss: 0.5599 | train_acc: 0.7398 | validation_loss: 0.5331 | validation_acc: 0.7695
# Epoch: 10 | train_loss: 0.5546 | train_acc: 0.7535 | validation_loss: 0.5261 | validation_acc: 0.7520
# Epoch: 11 | train_loss: 0.5309 | train_acc: 0.7515 | validation_loss: 0.5468 | validation_acc: 0.7734
# Epoch: 12 | train_loss: 0.5262 | train_acc: 0.7615 | validation_loss: 1.1945 | validation_acc: 0.5332
# Epoch: 13 | train_loss: 0.4964 | train_acc: 0.7702 | validation_loss: 0.9723 | validation_acc: 0.6250
# Epoch: 14 | train_loss: 0.5024 | train_acc: 0.7660 | validation_loss: 0.9108 | validation_acc: 0.6680
# Epoch: 15 | train_loss: 0.4820 | train_acc: 0.7823 | validation_loss: 0.7838 | validation_acc: 0.6992
# Epoch: 16 | train_loss: 0.4927 | train_acc: 0.7722 | validation_loss: 0.6744 | validation_acc: 0.7363
# Epoch: 17 | train_loss: 0.4690 | train_acc: 0.7823 | validation_loss: 1.4458 | validation_acc: 0.5977
# Epoch: 18 | train_loss: 0.4520 | train_acc: 0.7905 | validation_loss: 0.7479 | validation_acc: 0.7031
# Epoch: 19 | train_loss: 0.4526 | train_acc: 0.7925 | validation_loss: 2.6343 | validation_acc: 0.4668
# Epoch: 20 | train_loss: 0.4547 | train_acc: 0.7927 | validation_loss: 0.7724 | validation_acc: 0.7148
# Epoch: 21 | train_loss: 0.4381 | train_acc: 0.8007 | validation_loss: 0.7808 | validation_acc: 0.6934
# Epoch: 22 | train_loss: 0.4308 | train_acc: 0.8020 | validation_loss: 1.7550 | validation_acc: 0.6211
# Epoch: 23 | train_loss: 0.4186 | train_acc: 0.8153 | validation_loss: 1.0626 | validation_acc: 0.6523
# Epoch: 24 | train_loss: 0.4118 | train_acc: 0.8075 | validation_loss: 1.4693 | validation_acc: 0.6250
# Epoch: 25 | train_loss: 0.4177 | train_acc: 0.8105 | validation_loss: 1.0744 | validation_acc: 0.6406
# Epoch: 26 | train_loss: 0.4144 | train_acc: 0.8070 | validation_loss: 0.7230 | validation_acc: 0.7402
# Epoch: 27 | train_loss: 0.4050 | train_acc: 0.8137 | validation_loss: 0.8302 | validation_acc: 0.6934
# Epoch: 28 | train_loss: 0.3979 | train_acc: 0.8233 | validation_loss: 0.6962 | validation_acc: 0.7324
# Epoch: 29 | train_loss: 0.3998 | train_acc: 0.8237 | validation_loss: 2.2125 | validation_acc: 0.4883
# Epoch: 30 | train_loss: 0.3805 | train_acc: 0.8253 | validation_loss: 0.6315 | validation_acc: 0.7559
# Epoch: 31 | train_loss: 0.3785 | train_acc: 0.8260 | validation_loss: 1.3474 | validation_acc: 0.6426
# Epoch: 32 | train_loss: 0.3937 | train_acc: 0.8187 | validation_loss: 0.8096 | validation_acc: 0.6719
# Epoch: 33 | train_loss: 0.3732 | train_acc: 0.8340 | validation_loss: 1.4744 | validation_acc: 0.6445
# Epoch: 34 | train_loss: 0.3723 | train_acc: 0.8310 | validation_loss: 0.8341 | validation_acc: 0.6953
# Epoch: 35 | train_loss: 0.3813 | train_acc: 0.8315 | validation_loss: 1.5487 | validation_acc: 0.6543
# Epoch: 36 | train_loss: 0.3737 | train_acc: 0.8303 | validation_loss: 0.9453 | validation_acc: 0.7090
# Epoch: 37 | train_loss: 0.3648 | train_acc: 0.8395 | validation_loss: 0.8919 | validation_acc: 0.7090
# Epoch: 38 | train_loss: 0.3570 | train_acc: 0.8383 | validation_loss: 0.8138 | validation_acc: 0.7305
# Epoch: 39 | train_loss: 0.3509 | train_acc: 0.8455 | validation_loss: 0.6662 | validation_acc: 0.7480
# Epoch: 40 | train_loss: 0.3357 | train_acc: 0.8480 | validation_loss: 1.8264 | validation_acc: 0.6094
# Epoch: 41 | train_loss: 0.3605 | train_acc: 0.8433 | validation_loss: 1.0506 | validation_acc: 0.6738
# Epoch: 42 | train_loss: 0.3375 | train_acc: 0.8495 | validation_loss: 0.7529 | validation_acc: 0.7188
# Epoch: 43 | train_loss: 0.3501 | train_acc: 0.8450 | validation_loss: 0.8294 | validation_acc: 0.7402
# Epoch: 44 | train_loss: 0.3518 | train_acc: 0.8450 | validation_loss: 0.7878 | validation_acc: 0.7344
# Epoch: 45 | train_loss: 0.3500 | train_acc: 0.8405 | validation_loss: 0.9067 | validation_acc: 0.7109
# Epoch: 46 | train_loss: 0.3482 | train_acc: 0.8442 | validation_loss: 0.8836 | validation_acc: 0.7148
# Epoch: 47 | train_loss: 0.3347 | train_acc: 0.8545 | validation_loss: 3.1634 | validation_acc: 0.4844
# Epoch: 48 | train_loss: 0.3442 | train_acc: 0.8448 | validation_loss: 1.1253 | validation_acc: 0.6816
# Epoch: 49 | train_loss: 0.3378 | train_acc: 0.8518 | validation_loss: 0.5483 | validation_acc: 0.7852
# Epoch: 50 | train_loss: 0.3315 | train_acc: 0.8558 | validation_loss: 1.1445 | validation_acc: 0.6113
# Epoch: 51 | train_loss: 0.3304 | train_acc: 0.8548 | validation_loss: 0.7268 | validation_acc: 0.7461
# Epoch: 52 | train_loss: 0.3268 | train_acc: 0.8592 | validation_loss: 0.9991 | validation_acc: 0.7324
# Epoch: 53 | train_loss: 0.3322 | train_acc: 0.8505 | validation_loss: 1.5145 | validation_acc: 0.6016
# Epoch: 54 | train_loss: 0.3187 | train_acc: 0.8580 | validation_loss: 1.8168 | validation_acc: 0.5859
# Epoch: 55 | train_loss: 0.3098 | train_acc: 0.8640 | validation_loss: 1.2421 | validation_acc: 0.6680
# Epoch: 56 | train_loss: 0.3216 | train_acc: 0.8668 | validation_loss: 0.8059 | validation_acc: 0.6836
# Epoch: 57 | train_loss: 0.3148 | train_acc: 0.8612 | validation_loss: 0.8555 | validation_acc: 0.7754
# Epoch: 58 | train_loss: 0.3096 | train_acc: 0.8692 | validation_loss: 0.6045 | validation_acc: 0.7988
# Epoch: 59 | train_loss: 0.3162 | train_acc: 0.8628 | validation_loss: 0.9208 | validation_acc: 0.7402
# Epoch: 60 | train_loss: 0.3212 | train_acc: 0.8592 | validation_loss: 1.0873 | validation_acc: 0.7383
# Epoch: 61 | train_loss: 0.3023 | train_acc: 0.8625 | validation_loss: 0.6825 | validation_acc: 0.7617
# Epoch: 62 | train_loss: 0.3065 | train_acc: 0.8602 | validation_loss: 0.7797 | validation_acc: 0.7754
# Epoch: 63 | train_loss: 0.2946 | train_acc: 0.8678 | validation_loss: 2.2410 | validation_acc: 0.5000
# Epoch: 64 | train_loss: 0.3145 | train_acc: 0.8620 | validation_loss: 1.0558 | validation_acc: 0.6992
# Epoch: 65 | train_loss: 0.3097 | train_acc: 0.8685 | validation_loss: 1.0252 | validation_acc: 0.7285
# Epoch: 66 | train_loss: 0.2922 | train_acc: 0.8740 | validation_loss: 0.7291 | validation_acc: 0.7344
# Epoch: 67 | train_loss: 0.3013 | train_acc: 0.8678 | validation_loss: 0.7123 | validation_acc: 0.7617
# Epoch: 68 | train_loss: 0.3003 | train_acc: 0.8670 | validation_loss: 1.8508 | validation_acc: 0.5898
# Epoch: 69 | train_loss: 0.2903 | train_acc: 0.8712 | validation_loss: 1.3008 | validation_acc: 0.6992
# Epoch: 70 | train_loss: 0.2768 | train_acc: 0.8800 | validation_loss: 1.3748 | validation_acc: 0.6465
# Epoch: 71 | train_loss: 0.2914 | train_acc: 0.8698 | validation_loss: 0.9021 | validation_acc: 0.7012
# Epoch: 72 | train_loss: 0.3007 | train_acc: 0.8720 | validation_loss: 1.1024 | validation_acc: 0.7266
# Epoch: 73 | train_loss: 0.2907 | train_acc: 0.8770 | validation_loss: 1.1512 | validation_acc: 0.6699
# Epoch: 74 | train_loss: 0.2903 | train_acc: 0.8710 | validation_loss: 0.9139 | validation_acc: 0.7148
# Epoch: 75 | train_loss: 0.3064 | train_acc: 0.8638 | validation_loss: 1.2560 | validation_acc: 0.7090
# Epoch: 76 | train_loss: 0.2892 | train_acc: 0.8775 | validation_loss: 0.6758 | validation_acc: 0.7832
# Epoch: 77 | train_loss: 0.2742 | train_acc: 0.8790 | validation_loss: 0.7181 | validation_acc: 0.7363
# Epoch: 78 | train_loss: 0.2864 | train_acc: 0.8750 | validation_loss: 3.6187 | validation_acc: 0.4512
# Epoch: 79 | train_loss: 0.2700 | train_acc: 0.8795 | validation_loss: 1.0019 | validation_acc: 0.7344
# Epoch: 80 | train_loss: 0.2782 | train_acc: 0.8770 | validation_loss: 1.0115 | validation_acc: 0.7285
# Epoch: 81 | train_loss: 0.2722 | train_acc: 0.8818 | validation_loss: 0.7686 | validation_acc: 0.7539
# Epoch: 82 | train_loss: 0.2599 | train_acc: 0.8908 | validation_loss: 1.2781 | validation_acc: 0.6758
# Epoch: 83 | train_loss: 0.2784 | train_acc: 0.8768 | validation_loss: 1.6873 | validation_acc: 0.6816
# Epoch: 84 | train_loss: 0.2735 | train_acc: 0.8792 | validation_loss: 1.0408 | validation_acc: 0.7656
# Epoch: 85 | train_loss: 0.2726 | train_acc: 0.8835 | validation_loss: 1.0284 | validation_acc: 0.7363
# Epoch: 86 | train_loss: 0.2672 | train_acc: 0.8810 | validation_loss: 0.9154 | validation_acc: 0.7383
# Epoch: 87 | train_loss: 0.2756 | train_acc: 0.8792 | validation_loss: 0.9068 | validation_acc: 0.7480
# Epoch: 88 | train_loss: 0.2612 | train_acc: 0.8865 | validation_loss: 0.7869 | validation_acc: 0.7441
# Epoch: 89 | train_loss: 0.2680 | train_acc: 0.8842 | validation_loss: 0.8565 | validation_acc: 0.7441
# Epoch: 90 | train_loss: 0.2767 | train_acc: 0.8752 | validation_loss: 1.5332 | validation_acc: 0.6641
# Epoch: 91 | train_loss: 0.2623 | train_acc: 0.8858 | validation_loss: 0.9581 | validation_acc: 0.7441
# Epoch: 92 | train_loss: 0.2647 | train_acc: 0.8890 | validation_loss: 0.8196 | validation_acc: 0.7480
# Epoch: 93 | train_loss: 0.2596 | train_acc: 0.8910 | validation_loss: 0.7233 | validation_acc: 0.7715
# Epoch: 94 | train_loss: 0.2571 | train_acc: 0.8880 | validation_loss: 1.1760 | validation_acc: 0.7266
# Epoch: 95 | train_loss: 0.2450 | train_acc: 0.8910 | validation_loss: 1.1098 | validation_acc: 0.7031
# Epoch: 96 | train_loss: 0.2630 | train_acc: 0.8885 | validation_loss: 0.9666 | validation_acc: 0.6992
# Epoch: 97 | train_loss: 0.2558 | train_acc: 0.8910 | validation_loss: 0.7039 | validation_acc: 0.7422
# Epoch: 98 | train_loss: 0.2496 | train_acc: 0.8892 | validation_loss: 1.1425 | validation_acc: 0.7422
# Epoch: 99 | train_loss: 0.2489 | train_acc: 0.8935 | validation_loss: 1.2810 | validation_acc: 0.6680
# Epoch: 100 | train_loss: 0.2590 | train_acc: 0.8885 | validation_loss: 1.1102 | validation_acc: 0.6953

# %%
eval_resnet18_results = eval_model(resnet18, test_dl, loss_fn = loss_fn, accuracy_fn=accuracy_fn, device = device, dummy_input= torch.rand(16, 3, resize[0], resize[1]).to(device))
resnet18_results = [train_resnet18_results, train_time_resnet18, eval_resnet18_results]
final_save(model_folder_path,model_name, NUM_EPOCHS, resnet18, resnet18_results)
# Out:
#   0%|          | 0/32 [00:01<?, ?it/s]

# %%
model_name = "MobileNetSmall_Noise"
model_folder_path = models_path / model_name
check_dir(model_folder_path)
model_name_folder_path = model_folder_path / model_name

#Train MobileNetV3 Small
mobnet_sml.to(device)
nadam_optim = torch.optim.NAdam(params=mobnet_sml.parameters(), lr=lr)
train_mobnet_sml_results, train_time_mobnet_sml = train(mobnet_sml, train_dl, validation_dl, optimizer=nadam_optim, loss_fn=loss_fn, epochs=NUM_EPOCHS, name_save=model_name_folder_path, device=device)
# Out:
# Models\MobileNetSmall_Noise does not exist, creating one...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1934 | train_acc: 0.4335 | validation_loss: 0.8072 | validation_acc: 0.6270
# Epoch: 2 | train_loss: 0.8742 | train_acc: 0.5797 | validation_loss: 0.8941 | validation_acc: 0.5234
# Epoch: 3 | train_loss: 0.7783 | train_acc: 0.6392 | validation_loss: 0.9569 | validation_acc: 0.5254
# Epoch: 4 | train_loss: 0.7156 | train_acc: 0.6587 | validation_loss: 0.6754 | validation_acc: 0.6348
# Epoch: 5 | train_loss: 0.6659 | train_acc: 0.6865 | validation_loss: 0.7214 | validation_acc: 0.6777
# Epoch: 6 | train_loss: 0.6052 | train_acc: 0.7130 | validation_loss: 0.8207 | validation_acc: 0.5508
# Epoch: 7 | train_loss: 0.5930 | train_acc: 0.7258 | validation_loss: 0.7476 | validation_acc: 0.6309
# Epoch: 8 | train_loss: 0.5460 | train_acc: 0.7420 | validation_loss: 0.6273 | validation_acc: 0.7324
# Epoch: 9 | train_loss: 0.5387 | train_acc: 0.7472 | validation_loss: 0.6069 | validation_acc: 0.7617
# Epoch: 10 | train_loss: 0.5038 | train_acc: 0.7615 | validation_loss: 0.7165 | validation_acc: 0.7305
# Epoch: 11 | train_loss: 0.5104 | train_acc: 0.7555 | validation_loss: 0.8589 | validation_acc: 0.6016
# Epoch: 12 | train_loss: 0.4688 | train_acc: 0.7808 | validation_loss: 0.7449 | validation_acc: 0.6699
# Epoch: 13 | train_loss: 0.4490 | train_acc: 0.7877 | validation_loss: 0.7749 | validation_acc: 0.7168
# Epoch: 14 | train_loss: 0.4428 | train_acc: 0.8013 | validation_loss: 0.6617 | validation_acc: 0.7168
# Epoch: 15 | train_loss: 0.4325 | train_acc: 0.8077 | validation_loss: 0.8904 | validation_acc: 0.6758
# Epoch: 16 | train_loss: 0.4281 | train_acc: 0.8033 | validation_loss: 0.8410 | validation_acc: 0.7012
# Epoch: 17 | train_loss: 0.4136 | train_acc: 0.8133 | validation_loss: 0.6997 | validation_acc: 0.7285
# Epoch: 18 | train_loss: 0.3925 | train_acc: 0.8210 | validation_loss: 0.9773 | validation_acc: 0.6855
# Epoch: 19 | train_loss: 0.4179 | train_acc: 0.8093 | validation_loss: 1.1532 | validation_acc: 0.6836
# Epoch: 20 | train_loss: 0.3866 | train_acc: 0.8215 | validation_loss: 1.3248 | validation_acc: 0.6680
# Epoch: 21 | train_loss: 0.3893 | train_acc: 0.8187 | validation_loss: 0.8577 | validation_acc: 0.6816
# Epoch: 22 | train_loss: 0.3721 | train_acc: 0.8237 | validation_loss: 0.8099 | validation_acc: 0.7441
# Epoch: 23 | train_loss: 0.3753 | train_acc: 0.8367 | validation_loss: 0.9433 | validation_acc: 0.6973
# Epoch: 24 | train_loss: 0.3696 | train_acc: 0.8337 | validation_loss: 0.6040 | validation_acc: 0.7812
# Epoch: 25 | train_loss: 0.3452 | train_acc: 0.8415 | validation_loss: 0.7175 | validation_acc: 0.7715
# Epoch: 26 | train_loss: 0.3571 | train_acc: 0.8423 | validation_loss: 0.8130 | validation_acc: 0.7344
# Epoch: 27 | train_loss: 0.3471 | train_acc: 0.8423 | validation_loss: 0.9991 | validation_acc: 0.7500
# Epoch: 28 | train_loss: 0.3527 | train_acc: 0.8442 | validation_loss: 0.6786 | validation_acc: 0.7129
# Epoch: 29 | train_loss: 0.3332 | train_acc: 0.8472 | validation_loss: 0.7203 | validation_acc: 0.7539
# Epoch: 30 | train_loss: 0.3291 | train_acc: 0.8515 | validation_loss: 1.3327 | validation_acc: 0.7188
# Epoch: 31 | train_loss: 0.3311 | train_acc: 0.8500 | validation_loss: 0.8479 | validation_acc: 0.7598
# Epoch: 32 | train_loss: 0.3245 | train_acc: 0.8555 | validation_loss: 0.8582 | validation_acc: 0.7461
# Epoch: 33 | train_loss: 0.3257 | train_acc: 0.8602 | validation_loss: 1.1390 | validation_acc: 0.7402
# Epoch: 34 | train_loss: 0.3160 | train_acc: 0.8542 | validation_loss: 1.1398 | validation_acc: 0.7305
# Epoch: 35 | train_loss: 0.3091 | train_acc: 0.8595 | validation_loss: 1.2126 | validation_acc: 0.7305
# Epoch: 36 | train_loss: 0.3260 | train_acc: 0.8542 | validation_loss: 1.1732 | validation_acc: 0.6699
# Epoch: 37 | train_loss: 0.3140 | train_acc: 0.8590 | validation_loss: 0.9070 | validation_acc: 0.7266
# Epoch: 38 | train_loss: 0.3047 | train_acc: 0.8675 | validation_loss: 0.9909 | validation_acc: 0.7617
# Epoch: 39 | train_loss: 0.3057 | train_acc: 0.8618 | validation_loss: 1.2916 | validation_acc: 0.7051
# Epoch: 40 | train_loss: 0.3134 | train_acc: 0.8612 | validation_loss: 1.2233 | validation_acc: 0.7266
# Epoch: 41 | train_loss: 0.3237 | train_acc: 0.8530 | validation_loss: 0.6412 | validation_acc: 0.8066
# Epoch: 42 | train_loss: 0.2979 | train_acc: 0.8658 | validation_loss: 0.7671 | validation_acc: 0.7461
# Epoch: 43 | train_loss: 0.2848 | train_acc: 0.8718 | validation_loss: 1.0429 | validation_acc: 0.6836
# Epoch: 44 | train_loss: 0.2813 | train_acc: 0.8788 | validation_loss: 1.2728 | validation_acc: 0.6543
# Epoch: 45 | train_loss: 0.3005 | train_acc: 0.8655 | validation_loss: 0.9202 | validation_acc: 0.7090
# Epoch: 46 | train_loss: 0.3000 | train_acc: 0.8695 | validation_loss: 0.8459 | validation_acc: 0.8125
# Epoch: 47 | train_loss: 0.2851 | train_acc: 0.8700 | validation_loss: 0.9519 | validation_acc: 0.7383
# Epoch: 48 | train_loss: 0.3020 | train_acc: 0.8638 | validation_loss: 0.9185 | validation_acc: 0.7500
# Epoch: 49 | train_loss: 0.2672 | train_acc: 0.8830 | validation_loss: 0.9688 | validation_acc: 0.7461
# Epoch: 50 | train_loss: 0.2933 | train_acc: 0.8698 | validation_loss: 0.9814 | validation_acc: 0.7539
# Epoch: 51 | train_loss: 0.2701 | train_acc: 0.8815 | validation_loss: 1.2017 | validation_acc: 0.7207
# Epoch: 52 | train_loss: 0.2943 | train_acc: 0.8688 | validation_loss: 1.1003 | validation_acc: 0.7285
# Epoch: 53 | train_loss: 0.2630 | train_acc: 0.8840 | validation_loss: 0.7935 | validation_acc: 0.7871
# Epoch: 54 | train_loss: 0.2853 | train_acc: 0.8680 | validation_loss: 1.1431 | validation_acc: 0.7344
# Epoch: 55 | train_loss: 0.2611 | train_acc: 0.8845 | validation_loss: 1.1249 | validation_acc: 0.7578
# Epoch: 56 | train_loss: 0.2591 | train_acc: 0.8828 | validation_loss: 1.1021 | validation_acc: 0.7266
# Epoch: 57 | train_loss: 0.2712 | train_acc: 0.8765 | validation_loss: 1.6763 | validation_acc: 0.6895
# Epoch: 58 | train_loss: 0.2690 | train_acc: 0.8800 | validation_loss: 0.9934 | validation_acc: 0.7188
# Epoch: 59 | train_loss: 0.2611 | train_acc: 0.8845 | validation_loss: 1.0003 | validation_acc: 0.7539
# Epoch: 60 | train_loss: 0.2551 | train_acc: 0.8898 | validation_loss: 1.1944 | validation_acc: 0.7188
# Epoch: 61 | train_loss: 0.2528 | train_acc: 0.8888 | validation_loss: 1.3352 | validation_acc: 0.7109
# Epoch: 62 | train_loss: 0.2674 | train_acc: 0.8780 | validation_loss: 1.3614 | validation_acc: 0.7578
# Epoch: 63 | train_loss: 0.2616 | train_acc: 0.8855 | validation_loss: 0.8701 | validation_acc: 0.7773
# Epoch: 64 | train_loss: 0.2610 | train_acc: 0.8838 | validation_loss: 1.4790 | validation_acc: 0.7324
# Epoch: 65 | train_loss: 0.2354 | train_acc: 0.8932 | validation_loss: 1.1361 | validation_acc: 0.7422
# Epoch: 66 | train_loss: 0.2431 | train_acc: 0.8898 | validation_loss: 1.1807 | validation_acc: 0.7578
# Epoch: 67 | train_loss: 0.2587 | train_acc: 0.8878 | validation_loss: 1.2838 | validation_acc: 0.7246
# Epoch: 68 | train_loss: 0.2605 | train_acc: 0.8860 | validation_loss: 1.5406 | validation_acc: 0.6582
# Epoch: 69 | train_loss: 0.2478 | train_acc: 0.8862 | validation_loss: 1.1644 | validation_acc: 0.7324
# Epoch: 70 | train_loss: 0.2297 | train_acc: 0.8985 | validation_loss: 1.1792 | validation_acc: 0.7363
# Epoch: 71 | train_loss: 0.2353 | train_acc: 0.9018 | validation_loss: 1.3941 | validation_acc: 0.6953
# Epoch: 72 | train_loss: 0.2375 | train_acc: 0.8955 | validation_loss: 1.1086 | validation_acc: 0.7832
# Epoch: 73 | train_loss: 0.2374 | train_acc: 0.8958 | validation_loss: 0.9805 | validation_acc: 0.7832
# Epoch: 74 | train_loss: 0.2347 | train_acc: 0.9022 | validation_loss: 1.3102 | validation_acc: 0.7266
# Epoch: 75 | train_loss: 0.2296 | train_acc: 0.9012 | validation_loss: 1.0480 | validation_acc: 0.7520
# Epoch: 76 | train_loss: 0.2329 | train_acc: 0.8965 | validation_loss: 1.4944 | validation_acc: 0.7422
# Epoch: 77 | train_loss: 0.2447 | train_acc: 0.8915 | validation_loss: 1.0077 | validation_acc: 0.7617
# Epoch: 78 | train_loss: 0.2193 | train_acc: 0.9038 | validation_loss: 1.1519 | validation_acc: 0.7617
# Epoch: 79 | train_loss: 0.2175 | train_acc: 0.9067 | validation_loss: 0.9468 | validation_acc: 0.7793
# Epoch: 80 | train_loss: 0.2287 | train_acc: 0.8992 | validation_loss: 1.4633 | validation_acc: 0.7695
# Epoch: 81 | train_loss: 0.2240 | train_acc: 0.9032 | validation_loss: 1.4459 | validation_acc: 0.7637
# Epoch: 82 | train_loss: 0.2227 | train_acc: 0.8982 | validation_loss: 1.5301 | validation_acc: 0.6875
# Epoch: 83 | train_loss: 0.2325 | train_acc: 0.9010 | validation_loss: 1.0483 | validation_acc: 0.7480
# Epoch: 84 | train_loss: 0.2241 | train_acc: 0.9042 | validation_loss: 1.1944 | validation_acc: 0.7344
# Epoch: 85 | train_loss: 0.2223 | train_acc: 0.9035 | validation_loss: 1.1073 | validation_acc: 0.7637
# Epoch: 86 | train_loss: 0.2221 | train_acc: 0.9077 | validation_loss: 1.3225 | validation_acc: 0.7129
# Epoch: 87 | train_loss: 0.2135 | train_acc: 0.9097 | validation_loss: 1.1545 | validation_acc: 0.7754
# Epoch: 88 | train_loss: 0.2121 | train_acc: 0.9125 | validation_loss: 1.3891 | validation_acc: 0.7441
# Epoch: 89 | train_loss: 0.2375 | train_acc: 0.8978 | validation_loss: 1.0658 | validation_acc: 0.7637
# Epoch: 90 | train_loss: 0.2041 | train_acc: 0.9107 | validation_loss: 1.1172 | validation_acc: 0.7891
# Epoch: 91 | train_loss: 0.2213 | train_acc: 0.9075 | validation_loss: 0.9830 | validation_acc: 0.7949
# Epoch: 92 | train_loss: 0.2165 | train_acc: 0.9035 | validation_loss: 1.0972 | validation_acc: 0.7793
# Epoch: 93 | train_loss: 0.1991 | train_acc: 0.9097 | validation_loss: 1.5699 | validation_acc: 0.7305
# Epoch: 94 | train_loss: 0.2074 | train_acc: 0.9110 | validation_loss: 1.3757 | validation_acc: 0.7578
# Epoch: 95 | train_loss: 0.2103 | train_acc: 0.9090 | validation_loss: 1.6490 | validation_acc: 0.7422
# Epoch: 96 | train_loss: 0.2099 | train_acc: 0.9143 | validation_loss: 1.3329 | validation_acc: 0.7422
# Epoch: 97 | train_loss: 0.1992 | train_acc: 0.9110 | validation_loss: 0.7809 | validation_acc: 0.8203
# Epoch: 98 | train_loss: 0.1948 | train_acc: 0.9213 | validation_loss: 1.2047 | validation_acc: 0.7227
# Epoch: 99 | train_loss: 0.2019 | train_acc: 0.9140 | validation_loss: 1.3047 | validation_acc: 0.7461
# Epoch: 100 | train_loss: 0.2029 | train_acc: 0.9125 | validation_loss: 1.2613 | validation_acc: 0.7500

# %%
eval_mobnet_sml_results = eval_model(mobnet_sml, test_dl, loss_fn = loss_fn, accuracy_fn=accuracy_fn, device = device, dummy_input= torch.rand(16, 3, resize[0], resize[1]).to(device))
mobnet_sml_results = [train_mobnet_sml_results, train_time_mobnet_sml, eval_mobnet_sml_results]
final_save(model_folder_path,model_name, NUM_EPOCHS, mobnet_sml, mobnet_sml_results)
# Out:
#   0%|          | 0/32 [00:01<?, ?it/s]

# %%
model_name = "MobileNetLarge_Noise"
model_folder_path = models_path / model_name
check_dir(model_folder_path)
model_name_folder_path = model_folder_path / model_name

#Train MobileNetV3 Large
mobnet_lrg.to(device)
nadam_optim = torch.optim.NAdam(params=mobnet_lrg.parameters(), lr=lr)
train_mobnet_lrg_results, train_time_mobnet_lrg = train(mobnet_lrg, train_dl, validation_dl, optimizer=nadam_optim, loss_fn=loss_fn, epochs=NUM_EPOCHS, name_save=model_name_folder_path, device=device)
# Out:
# Models\MobileNetLarge_Noise does not exist, creating one...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1879 | train_acc: 0.4412 | validation_loss: 0.8951 | validation_acc: 0.5742
# Epoch: 2 | train_loss: 0.8549 | train_acc: 0.5958 | validation_loss: 0.8082 | validation_acc: 0.6055
# Epoch: 3 | train_loss: 0.7608 | train_acc: 0.6400 | validation_loss: 0.6166 | validation_acc: 0.7402
# Epoch: 4 | train_loss: 0.7562 | train_acc: 0.6335 | validation_loss: 0.7050 | validation_acc: 0.6055
# Epoch: 5 | train_loss: 0.6909 | train_acc: 0.6755 | validation_loss: 0.8770 | validation_acc: 0.6230
# Epoch: 6 | train_loss: 0.6909 | train_acc: 0.6810 | validation_loss: 0.6454 | validation_acc: 0.6758
# Epoch: 7 | train_loss: 0.6430 | train_acc: 0.6885 | validation_loss: 0.6136 | validation_acc: 0.7461
# Epoch: 8 | train_loss: 0.6170 | train_acc: 0.7000 | validation_loss: 0.7568 | validation_acc: 0.6504
# Epoch: 9 | train_loss: 0.6027 | train_acc: 0.7043 | validation_loss: 0.6974 | validation_acc: 0.6758
# Epoch: 10 | train_loss: 0.5766 | train_acc: 0.7085 | validation_loss: 0.5636 | validation_acc: 0.7402
# Epoch: 11 | train_loss: 0.5695 | train_acc: 0.7228 | validation_loss: 0.7639 | validation_acc: 0.6309
# Epoch: 12 | train_loss: 0.5440 | train_acc: 0.7318 | validation_loss: 1.1763 | validation_acc: 0.5293
# Epoch: 13 | train_loss: 0.5618 | train_acc: 0.7248 | validation_loss: 0.7357 | validation_acc: 0.6660
# Epoch: 14 | train_loss: 0.5247 | train_acc: 0.7445 | validation_loss: 1.1268 | validation_acc: 0.5898
# Epoch: 15 | train_loss: 0.5204 | train_acc: 0.7380 | validation_loss: 0.7665 | validation_acc: 0.6250
# Epoch: 16 | train_loss: 0.4972 | train_acc: 0.7548 | validation_loss: 0.9783 | validation_acc: 0.5742
# Epoch: 17 | train_loss: 0.4945 | train_acc: 0.7595 | validation_loss: 0.6477 | validation_acc: 0.7129
# Epoch: 18 | train_loss: 0.4971 | train_acc: 0.7652 | validation_loss: 0.6848 | validation_acc: 0.7148
# Epoch: 19 | train_loss: 0.4745 | train_acc: 0.7780 | validation_loss: 0.8807 | validation_acc: 0.6836
# Epoch: 20 | train_loss: 0.4531 | train_acc: 0.7835 | validation_loss: 1.0011 | validation_acc: 0.6777
# Epoch: 21 | train_loss: 0.4660 | train_acc: 0.7837 | validation_loss: 0.5989 | validation_acc: 0.7656
# Epoch: 22 | train_loss: 0.4246 | train_acc: 0.7995 | validation_loss: 0.7636 | validation_acc: 0.6660
# Epoch: 23 | train_loss: 0.4159 | train_acc: 0.8035 | validation_loss: 0.9323 | validation_acc: 0.6855
# Epoch: 24 | train_loss: 0.4107 | train_acc: 0.7990 | validation_loss: 0.9286 | validation_acc: 0.6699
# Epoch: 25 | train_loss: 0.4101 | train_acc: 0.7980 | validation_loss: 0.7606 | validation_acc: 0.7363
# Epoch: 26 | train_loss: 0.3895 | train_acc: 0.8210 | validation_loss: 1.4076 | validation_acc: 0.6719
# Epoch: 27 | train_loss: 0.4126 | train_acc: 0.8143 | validation_loss: 0.6287 | validation_acc: 0.7305
# Epoch: 28 | train_loss: 0.3848 | train_acc: 0.8250 | validation_loss: 0.7843 | validation_acc: 0.7305
# Epoch: 29 | train_loss: 0.3919 | train_acc: 0.8217 | validation_loss: 2.7401 | validation_acc: 0.4297
# Epoch: 30 | train_loss: 0.3822 | train_acc: 0.8190 | validation_loss: 0.9671 | validation_acc: 0.7148
# Epoch: 31 | train_loss: 0.3620 | train_acc: 0.8400 | validation_loss: 0.8296 | validation_acc: 0.7305
# Epoch: 32 | train_loss: 0.3855 | train_acc: 0.8245 | validation_loss: 0.9951 | validation_acc: 0.7246
# Epoch: 33 | train_loss: 0.3573 | train_acc: 0.8305 | validation_loss: 1.0179 | validation_acc: 0.7070
# Epoch: 34 | train_loss: 0.3464 | train_acc: 0.8395 | validation_loss: 5.5288 | validation_acc: 0.4336
# Epoch: 35 | train_loss: 0.3469 | train_acc: 0.8397 | validation_loss: 1.2411 | validation_acc: 0.6973
# Epoch: 36 | train_loss: 0.3592 | train_acc: 0.8365 | validation_loss: 0.9008 | validation_acc: 0.7109
# Epoch: 37 | train_loss: 0.3371 | train_acc: 0.8480 | validation_loss: 0.9782 | validation_acc: 0.6992
# Epoch: 38 | train_loss: 0.3282 | train_acc: 0.8480 | validation_loss: 0.9401 | validation_acc: 0.7383
# Epoch: 39 | train_loss: 0.3190 | train_acc: 0.8540 | validation_loss: 3.9828 | validation_acc: 0.5234
# Epoch: 40 | train_loss: 0.3192 | train_acc: 0.8558 | validation_loss: 1.0773 | validation_acc: 0.7500
# Epoch: 41 | train_loss: 0.3257 | train_acc: 0.8552 | validation_loss: 0.9532 | validation_acc: 0.7715
# Epoch: 42 | train_loss: 0.3241 | train_acc: 0.8565 | validation_loss: 1.1903 | validation_acc: 0.7090
# Epoch: 43 | train_loss: 0.3206 | train_acc: 0.8502 | validation_loss: 1.5408 | validation_acc: 0.7285
# Epoch: 44 | train_loss: 0.3155 | train_acc: 0.8508 | validation_loss: 3.8631 | validation_acc: 0.5059
# Epoch: 45 | train_loss: 0.3163 | train_acc: 0.8595 | validation_loss: 1.1374 | validation_acc: 0.7188
# Epoch: 46 | train_loss: 0.2999 | train_acc: 0.8642 | validation_loss: 1.2115 | validation_acc: 0.7168
# Epoch: 47 | train_loss: 0.3150 | train_acc: 0.8592 | validation_loss: 0.9854 | validation_acc: 0.7441
# Epoch: 48 | train_loss: 0.2996 | train_acc: 0.8668 | validation_loss: 1.3557 | validation_acc: 0.6387
# Epoch: 49 | train_loss: 0.2994 | train_acc: 0.8655 | validation_loss: 26.9564 | validation_acc: 0.4668
# Epoch: 50 | train_loss: 0.3068 | train_acc: 0.8622 | validation_loss: 1.2746 | validation_acc: 0.7188
# Epoch: 51 | train_loss: 0.3271 | train_acc: 0.8610 | validation_loss: 0.6702 | validation_acc: 0.7812
# Epoch: 52 | train_loss: 0.2973 | train_acc: 0.8650 | validation_loss: 1.4503 | validation_acc: 0.7109
# Epoch: 53 | train_loss: 0.2892 | train_acc: 0.8742 | validation_loss: 1.1773 | validation_acc: 0.7266
# Epoch: 54 | train_loss: 0.2909 | train_acc: 0.8720 | validation_loss: 1.0240 | validation_acc: 0.7246
# Epoch: 55 | train_loss: 0.2746 | train_acc: 0.8770 | validation_loss: 1.1289 | validation_acc: 0.7500
# Epoch: 56 | train_loss: 0.2864 | train_acc: 0.8725 | validation_loss: 1.3635 | validation_acc: 0.7031
# Epoch: 57 | train_loss: 0.2813 | train_acc: 0.8758 | validation_loss: 12.9486 | validation_acc: 0.4434
# Epoch: 58 | train_loss: 0.2995 | train_acc: 0.8690 | validation_loss: 10.6585 | validation_acc: 0.4609
# Epoch: 59 | train_loss: 0.2864 | train_acc: 0.8708 | validation_loss: 1.0791 | validation_acc: 0.7305
# Epoch: 60 | train_loss: 0.2867 | train_acc: 0.8705 | validation_loss: 0.8458 | validation_acc: 0.7422
# Epoch: 61 | train_loss: 0.2830 | train_acc: 0.8740 | validation_loss: 0.8843 | validation_acc: 0.7578
# Epoch: 62 | train_loss: 0.2799 | train_acc: 0.8812 | validation_loss: 0.8591 | validation_acc: 0.7695
# Epoch: 63 | train_loss: 0.2838 | train_acc: 0.8735 | validation_loss: 1.3795 | validation_acc: 0.7441
# Epoch: 64 | train_loss: 0.2637 | train_acc: 0.8898 | validation_loss: 0.9608 | validation_acc: 0.7617
# Epoch: 65 | train_loss: 0.2748 | train_acc: 0.8850 | validation_loss: 0.7759 | validation_acc: 0.7793
# Epoch: 66 | train_loss: 0.2790 | train_acc: 0.8795 | validation_loss: 1.1286 | validation_acc: 0.7422
# Epoch: 67 | train_loss: 0.2701 | train_acc: 0.8808 | validation_loss: 1.1021 | validation_acc: 0.7188
# Epoch: 68 | train_loss: 0.2679 | train_acc: 0.8858 | validation_loss: 1.0693 | validation_acc: 0.7773
# Epoch: 69 | train_loss: 0.2711 | train_acc: 0.8850 | validation_loss: 0.8501 | validation_acc: 0.7773
# Epoch: 70 | train_loss: 0.2727 | train_acc: 0.8802 | validation_loss: 0.9352 | validation_acc: 0.7500
# Epoch: 71 | train_loss: 0.2526 | train_acc: 0.8865 | validation_loss: 0.7122 | validation_acc: 0.7832
# Epoch: 72 | train_loss: 0.2549 | train_acc: 0.8940 | validation_loss: 1.2055 | validation_acc: 0.7773
# Epoch: 73 | train_loss: 0.4135 | train_acc: 0.8327 | validation_loss: 1.0486 | validation_acc: 0.7578
# Epoch: 74 | train_loss: 0.3180 | train_acc: 0.8665 | validation_loss: 0.9433 | validation_acc: 0.7441
# Epoch: 75 | train_loss: 0.2941 | train_acc: 0.8782 | validation_loss: 1.3041 | validation_acc: 0.7129
# Epoch: 76 | train_loss: 0.2753 | train_acc: 0.8800 | validation_loss: 0.9466 | validation_acc: 0.7344
# Epoch: 77 | train_loss: 0.2610 | train_acc: 0.8880 | validation_loss: 1.1596 | validation_acc: 0.7422
# Epoch: 78 | train_loss: 0.2666 | train_acc: 0.8925 | validation_loss: 1.0822 | validation_acc: 0.7324
# Epoch: 79 | train_loss: 0.2608 | train_acc: 0.8842 | validation_loss: 1.2596 | validation_acc: 0.7324
# Epoch: 80 | train_loss: 0.2509 | train_acc: 0.8900 | validation_loss: 1.0271 | validation_acc: 0.7480
# Epoch: 81 | train_loss: 0.2536 | train_acc: 0.8955 | validation_loss: 1.3114 | validation_acc: 0.7227
# Epoch: 82 | train_loss: 0.2528 | train_acc: 0.8962 | validation_loss: 0.9867 | validation_acc: 0.7441
# Epoch: 83 | train_loss: 0.2508 | train_acc: 0.8892 | validation_loss: 0.9366 | validation_acc: 0.7559
# Epoch: 84 | train_loss: 0.2418 | train_acc: 0.8948 | validation_loss: 1.4506 | validation_acc: 0.7598
# Epoch: 85 | train_loss: 0.2736 | train_acc: 0.8888 | validation_loss: 1.1259 | validation_acc: 0.7559
# Epoch: 86 | train_loss: 0.2447 | train_acc: 0.8945 | validation_loss: 0.9797 | validation_acc: 0.7754
# Epoch: 87 | train_loss: 0.2362 | train_acc: 0.8980 | validation_loss: 0.9420 | validation_acc: 0.7695
# Epoch: 88 | train_loss: 0.2424 | train_acc: 0.8952 | validation_loss: 1.6280 | validation_acc: 0.7305
# Epoch: 89 | train_loss: 0.2491 | train_acc: 0.8928 | validation_loss: 1.1715 | validation_acc: 0.7793
# Epoch: 90 | train_loss: 0.2279 | train_acc: 0.9022 | validation_loss: 1.2995 | validation_acc: 0.7520
# Epoch: 91 | train_loss: 0.2363 | train_acc: 0.8995 | validation_loss: 1.2770 | validation_acc: 0.7422
# Epoch: 92 | train_loss: 0.2364 | train_acc: 0.8985 | validation_loss: 1.4970 | validation_acc: 0.7383
# Epoch: 93 | train_loss: 0.2522 | train_acc: 0.8928 | validation_loss: 1.0119 | validation_acc: 0.7461
# Epoch: 94 | train_loss: 0.2209 | train_acc: 0.9048 | validation_loss: 1.4496 | validation_acc: 0.7578
# Epoch: 95 | train_loss: 0.2315 | train_acc: 0.8970 | validation_loss: 1.3662 | validation_acc: 0.7676
# Epoch: 96 | train_loss: 0.2384 | train_acc: 0.8958 | validation_loss: 2.3841 | validation_acc: 0.5234
# Epoch: 97 | train_loss: 0.2404 | train_acc: 0.8955 | validation_loss: 1.2817 | validation_acc: 0.7402
# Epoch: 98 | train_loss: 0.2611 | train_acc: 0.8892 | validation_loss: 1.4322 | validation_acc: 0.7422
# Epoch: 99 | train_loss: 0.2207 | train_acc: 0.9015 | validation_loss: 2.0381 | validation_acc: 0.7344
# Epoch: 100 | train_loss: 0.2282 | train_acc: 0.9038 | validation_loss: 1.1693 | validation_acc: 0.7676

# %%
eval_mobnet_lrg_results = eval_model(mobnet_lrg, test_dl, loss_fn = loss_fn, accuracy_fn=accuracy_fn, device = device, dummy_input= torch.rand(16, 3, resize[0], resize[1]).to(device))
mobnet_lrg_results = [train_mobnet_lrg_results, train_time_mobnet_lrg, eval_mobnet_lrg_results]
final_save(model_folder_path, model_name, NUM_EPOCHS, mobnet_lrg, mobnet_lrg_results)
# Out:
#   0%|          | 0/32 [00:02<?, ?it/s]

# %%
model_name = "EfficientNetB0_Noise"
model_folder_path = models_path / model_name
check_dir(model_folder_path)
model_name_folder_path = model_folder_path / model_name

#Train EfficientNet B0
effnetb0.to(device)
nadam_optim = torch.optim.NAdam(params=effnetb0.parameters(), lr=lr)
train_effnetb0_results, train_time_effnetb0 = train(effnetb0, train_dl, validation_dl, optimizer=nadam_optim, loss_fn=loss_fn, epochs=NUM_EPOCHS, name_save=model_name_folder_path, device=device)
# Out:
# Models\EfficientNetB0_Noise does not exist, creating one...
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.4119 | train_acc: 0.3312 | validation_loss: 1.0795 | validation_acc: 0.4277
# Epoch: 2 | train_loss: 0.9068 | train_acc: 0.5625 | validation_loss: 0.7349 | validation_acc: 0.5977
# Epoch: 3 | train_loss: 0.7735 | train_acc: 0.6132 | validation_loss: 0.6633 | validation_acc: 0.7031
# Epoch: 4 | train_loss: 0.7310 | train_acc: 0.6492 | validation_loss: 0.6159 | validation_acc: 0.7207
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19316\2120847212.py in <module>
#       7 effnetb0.to(device)
#       8 nadam_optim = torch.optim.NAdam(params=effnetb0.parameters(), lr=lr)
# ----> 9 train_effnetb0_results, train_time_effnetb0 = train(effnetb0, train_dl, validation_dl, optimizer=nadam_optim, loss_fn=loss_fn, epochs=NUM_EPOCHS, name_save=model_name_folder_path, device=device)
#
# c:\Users\joaor\Desktop\AQAUIS\AQAUIS\Code\engine.py in train(model, train_dataloader, validation_dataloader, optimizer, loss_fn, epochs, name_save, device)
#     109
#     110   for epoch in tqdm(range(epochs)):
# --> 111     train_loss, train_acc = train_step(model=model,
#     112                                        dataloader=train_dataloader,
#     113                                        loss_fn=loss_fn,
#
# c:\Users\joaor\Desktop\AQAUIS\AQAUIS\Code\engine.py in train_step(model, dataloader, loss_fn, optimizer, device)
#      19     train_loss, train_acc = 0,0
#      20
# ---> 21     for batch, (X, y) in enumerate(dataloader):
#      22         X, y = X.to(device), y.to(device)
#      23
#
# c:\Users\joaor\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __iter__(self)
#     433             return self._iterator
#     434         else:
# --> 435             return self._get_iterator()
#     436
#     437     @property
#
# c:\Users\joaor\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in _get_iterator(self)
#     379         else:
#     380             self.check_worker_number_rationality()
# --> 381             return _MultiProcessingDataLoaderIter(self)
#     382
#     383     @property
#
# c:\Users\joaor\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __init__(self, loader)
#    1032             #     before it starts, and __del__ tries to join but will get:
#    1033             #     AssertionError: can only join a started process.
# -> 1034             w.start()
#    1035             self._index_queues.append(index_queue)
#    1036             self._workers.append(w)
#
# c:\Users\joaor\anaconda3\lib\multiprocessing\process.py in start(self)
#     119                'daemonic processes are not allowed to have children'
#     120         _cleanup()
# --> 121         self._popen = self._Popen(self)
#     122         self._sentinel = self._popen.sentinel
#     123         # Avoid a refcycle if the target function holds an indirect
#
# c:\Users\joaor\anaconda3\lib\multiprocessing\context.py in _Popen(process_obj)
#     222     @staticmethod
#     223     def _Popen(process_obj):
# --> 224         return _default_context.get_context().Process._Popen(process_obj)
#     225
#     226 class DefaultContext(BaseContext):
#
# c:\Users\joaor\anaconda3\lib\multiprocessing\context.py in _Popen(process_obj)
#     325         def _Popen(process_obj):
#     326             from .popen_spawn_win32 import Popen
# --> 327             return Popen(process_obj)
#     328
#     329     class SpawnContext(BaseContext):
#
# c:\Users\joaor\anaconda3\lib\multiprocessing\popen_spawn_win32.py in __init__(self, process_obj)
#      91             try:
#      92                 reduction.dump(prep_data, to_child)
# ---> 93                 reduction.dump(process_obj, to_child)
#      94             finally:
#      95                 set_spawning_popen(None)
#
# c:\Users\joaor\anaconda3\lib\multiprocessing\reduction.py in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#      61
#      62 #
#
# KeyboardInterrupt:

# %%
eval_effnetb0_results = eval_model(effnetb0, test_dl, loss_fn = loss_fn, accuracy_fn=accuracy_fn, device = device, dummy_input= torch.rand(16, 3, resize[0], resize[1]).to(device))
effnetb0_results = [train_effnetb0_results, train_time_effnetb0, eval_effnetb0_results]
final_save(model_folder_path, model_name, NUM_EPOCHS, effnetb0, effnetb0_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19316\1401836462.py in <module>
# ----> 1 eval_effnetb0_results = eval_model(effnetb0, test_dl, loss_fn = loss_fn, accuracy_fn=accuracy_fn, device = device, dummy_input= torch.rand(16, 3, resize[0], resize[1]).to(device))
#       2 effnetb0_results = [train_effnetb0_results, train_time_effnetb0, eval_effnetb0_results]
#       3 final_save(model_folder_path, model_name, NUM_EPOCHS, effnetb0, effnetb0_results)
#
# NameError: name 'eval_model' is not defined

# %% [markdown]
# Loading and evaluating models

# %%
model_name = "ResNet18_Noise"
model = ResNet18
res18_results, final_res18_model, best_res18_model = load_results_model(model_name, model, NUM_EPOCHS, 58, device)
final_res18_model.to(device), best_res18_model.to(device)
print("Done")
# Out:
# Done

# %%
#best_resnet18_eval_results = eval_model(best_res18_model,test_dl,loss_fn = loss_fn, accuracy_fn=accuracy_fn, device=device, dummy_input=torch.rand(16, 3, resize[0], resize[1]).to(device))
final_resnet18_eval_results = eval_model(final_res18_model,test_dl,loss_fn = loss_fn, accuracy_fn=accuracy_fn, device=device, dummy_input=torch.rand(16, 3, resize[0], resize[1]).to(device))
# Out:
#   0%|          | 0/32 [00:02<?, ?it/s]

# %%
model_name = "MobileNetSmall_Noise"
model = MobileNetSmall
mobnet_sml_results, final_mobnet_sml_model, best_mobnet_sml_model = load_results_model(model_name, model, NUM_EPOCHS, 97, device)
final_mobnet_sml_model.to(device), best_mobnet_sml_model.to(device)
print("Done")
# Out:
# Done

# %%
#best_mobnet_sml_eval_results = eval_model(best_mobnet_sml_model,test_dl,loss_fn = loss_fn, accuracy_fn=accuracy_fn, device=device, dummy_input=torch.rand(16, 3, resize[0], resize[1]).to(device))
final_mobnet_sml_eval_results = eval_model(final_mobnet_sml_model,test_dl,loss_fn = loss_fn, accuracy_fn=accuracy_fn, device=device, dummy_input=torch.rand(16, 3, resize[0], resize[1]).to(device))
# Out:
#   0%|          | 0/32 [00:03<?, ?it/s]

# %%
model_name = "MobileNetLarge_Noise"
model = MobileNetLarge
mobnet_lrg_results, final_mobnet_lrg_model, best_mobnet_lrg_model = load_results_model(model_name, model, NUM_EPOCHS, 71, device)
final_mobnet_lrg_model.to(device), best_mobnet_lrg_model.to(device)
print("Done")
# Out:
# Done

# %%
#best_mobnet_lrg_eval_results = eval_model(best_mobnet_lrg_model,test_dl,loss_fn = loss_fn, accuracy_fn=accuracy_fn, device=device, dummy_input=torch.rand(16, 3, resize[0], resize[1]).to(device))
final_mobnet_lrg_eval_results = eval_model(final_mobnet_lrg_model,test_dl,loss_fn = loss_fn, accuracy_fn=accuracy_fn, device=device, dummy_input=torch.rand(16, 3, resize[0], resize[1]).to(device))
# Out:
#   0%|          | 0/32 [00:02<?, ?it/s]

# %%
# model_name = "EfficientNetB0"
# model = EfficientNetB0
# effnetb0_results, final_effnetb0_model, best_effnetb0_model = load_results_model(model_name, model, NUM_EPOCHS, 42, device)
# final_effnetb0_model.to(device), best_effnetb0_model.to(device)
# print("Done")
# Out:
# Done

# %%
#best_effnetb0_eval_results = eval_model(best_effnetb0_model,test_dl,loss_fn = loss_fn, accuracy_fn=accuracy_fn, device=device, dummy_input=torch.rand(16, 3, resize[0], resize[1]).to(device))
#final_effnetb0_eval_results = eval_model(final_effnetb0_model,test_dl,loss_fn = loss_fn, accuracy_fn=accuracy_fn, device=device, dummy_input=torch.rand(16, 3, resize[0], resize[1]).to(device))
# Out:
#   0%|          | 0/32 [00:01<?, ?it/s]

# %%
plot_loss_curves(res18_results[0],"ResNet18"),plot_loss_curves(mobnet_sml_results[0],"MobileNet V3 Small"),
plot_loss_curves(mobnet_lrg_results[0],"MobileNet V3 Large"), #plot_loss_curves(effnetb0_results[0],"EfficientNet B0")#, plot_loss_curves(train_effnetb5_results,"EfficientNet B5"),
# Out:
# (None,)

# %%
plot_confusion_matrix(final_res18_model,test_dl,device,class_names, "ResNet18"), #plot_confusion_matrix(final_res50_model, test_dl, device, class_names, "ResNet50"),
plot_confusion_matrix(final_mobnet_lrg_model, test_dl, device, class_names, "MobileNetV3 Large"), plot_confusion_matrix(final_mobnet_sml_model, test_dl, device, class_names, "MobileNetV3 Small"),
#plot_confusion_matrix(final_effnetb0_model,test_dl,device,class_names, "EfficientNet B0")#, plot_confusion_matrix(effnetb5, test_dl, device, class_names, "EfficientNet B5")

# %%
results_table = pd.DataFrame([
    res18_results[2],
    #res50_results[2],
    mobnet_sml_results[2],
    mobnet_lrg_results[2],
    #effnetb0_results[2]
])

results_table
# Out:
#     model_name  model_loss  model_acc  model_inf_time  std_inf_time
# 0       ResNet    1.012893  74.609375       48.813599      8.051722
# 1  MobileNetV3    1.417630  74.023438       30.385248      9.189917
# 2  MobileNetV3    1.260908  75.976562       70.310816     14.900944

# %%
final_results_table = pd.DataFrame([
    final_resnet18_eval_results,
    final_resnet50_eval_results,
    final_mobnet_sml_eval_results,
    final_mobnet_lrg_eval_results,
    final_effnetb0_eval_results
])

final_results_table
# Out:
#      model_name  model_loss  model_acc  model_inf_time  std_inf_time
# 0        ResNet    0.806527  78.515625       50.178591     16.388231
# 1        ResNet    0.924027  75.781250      193.233504     23.708150
# 2   MobileNetV3    1.288821  75.390625       45.111967     38.564644
# 3   MobileNetV3    1.203084  72.851562       57.280160      6.902893
# 4  EfficientNet    1.068041  77.148438      130.588832     35.668292

# %%
best_results_table = pd.DataFrame([
    best_resnet18_eval_results,
    best_resnet50_eval_results,
    best_mobnet_sml_eval_results,
    best_mobnet_lrg_eval_results,
    best_effnetb0_eval_results
])

best_results_table
# Out:
#      model_name  model_loss  model_acc  model_inf_time  std_inf_time
# 0        ResNet    0.634344  79.101562       51.444093     20.696904
# 1        ResNet    0.448066  81.054688      215.152160     33.276489
# 2   MobileNetV3    0.606304  80.859375       29.873888     13.239567
# 3   MobileNetV3    0.709580  75.976562       62.787359     28.104239
# 4  EfficientNet    0.518238  80.273438      127.358079     17.353080
